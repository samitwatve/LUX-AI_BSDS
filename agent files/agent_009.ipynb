# %% [markdown]
# #### Import packages

# %%
import numpy as np
import pandas as pd
from kaggle_environments import make

from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES, Position
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
import math
import sys
import random
# Out:
# Loading environment football failed: No module named 'gfootball'

# %% [markdown]
# #### Functions to find resource related metrics

# %%
# this snippet finds all resources stored on the map and puts them into a list so we can search over them
def find_resources(game_state):
    resource_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if cell.has_resource():
                resource_tiles.append(cell)
    return resource_tiles

def find_resource_patches(game_state, player):
    width, height = game_state.map_width, game_state.map_height
    patches, patch_values = [], []
    for y in range(height):
        for x in range(width):
            if y % 4 == 0:
                if x % 4 == 0:
                    patches.append((x,y))

    for patch in patches:
        patch_resource_count = 0
        patch_city_tile_count = 0
        patch_enemy_city_tile_count = 0
        for x1 in range(patch[0], patch[0]+4):
            for y1 in range(patch[1], patch[1]+4):
                cell = game_state.map.get_cell(x1, y1)

                if cell.citytile is not None:
                    if cell.citytile.team == player:
                        patch_city_tile_count +=1
                    else:
                        patch_enemy_city_tile_count +=1
                    
                if cell.has_resource():
                    if cell.resource.type == Constants.RESOURCE_TYPES.URANIUM:
                        if player.researched_uranium(): 
                            patch_resource_count += 4
                  
                    elif cell.resource.type == Constants.RESOURCE_TYPES.COAL:
                        if player.researched_coal(): 
                            patch_resource_count += 2
                    else:
                        patch_resource_count += 1
        patch_values.append([patch, patch_resource_count, patch_city_tile_count, patch_enemy_city_tile_count])
            
    return(patch_values)

# the next snippet finds the closest resources that we can mine given position on a map
def find_closest_resources(pos, player, resource_tiles):
    closest_dist = math.inf
    closest_resource_tile = None
    for resource_tile in resource_tiles:
        # we skip over resources that we can't mine due to not having researched them
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL and not player.researched_coal(): continue
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM and not player.researched_uranium(): continue
        dist = resource_tile.pos.distance_to(pos)
        if dist < closest_dist:
            closest_dist = dist
            closest_resource_tile = resource_tile
    return closest_resource_tile

def find_resources_perimeter_tiles(game_state):
    perimeter_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    resource_tiles = find_resources(game_state)
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            for resource_tile in resource_tiles:
                if not cell.has_resource() and cell.pos.is_adjacent(resource_tile.pos) and not cell.citytile:
                    perimeter_tiles.append(cell)
    return perimeter_tiles
    
def find_closest_perimeter_tile(pos, player, perimeter_tiles):
    closest_dist = math.inf
    closest_perimeter_tile = None
    for perimeter_tile in perimeter_tiles:
        dist = perimeter_tile.pos.distance_to(pos)
        if dist < closest_dist:
            closest_dist = dist
            closest_perimeter_tile = perimeter_tile
    return closest_perimeter_tile

# %% [markdown]
# #### Functions to find city related metrics

# %%
def find_closest_city_tile(pos, player):
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        # the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
        # contains the information of all citytiles in that city
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                dist = city_tile.pos.distance_to(pos)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_city_tile = city_tile
    return closest_city_tile

def find_city_adjacent_empty_tiles(player):
    width, height = game_state.map_width, game_state.map_height
    adjacent_empty_tiles = []
    city_tiles_positions = []
    if len(player.cities) > 0:
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                city_tiles_positions.append(city_tile.pos)
                if city_tile.pos.x>=1 and  city_tile.pos.x < width and city_tile.pos.y >=1 and city_tile.pos.y < height:
                    for y in range(city_tile.pos.y-1, city_tile.pos.y+1):
                        for x in range(city_tile.pos.x-1, city_tile.pos.x+1):
                            cell = game_state.map.get_cell(x, y)
                            if cell.pos.is_adjacent(city_tile.pos):
                                for ctp in city_tiles_positions:
                                    if cell.pos.equals(ctp):
                                        continue
                                    else:
                                        if not cell.has_resource():
                                            adjacent_empty_tiles.append(cell)
    return adjacent_empty_tiles
        
def find_closest_uranium(pos, player, resource_tiles):
    closest_dist = math.inf
    closest_uranium_tile = None
    for resource_tile in resource_tiles:
        if not (resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM): continue    
        dist = resource_tile.pos.distance_to(pos)
        if dist < closest_dist:
            closest_dist = dist
            closest_uranium_tile = resource_tile
    return closest_uranium_tile


def find_closest_coal(pos, player, resource_tiles):
    closest_dist = math.inf
    closest_coal_tile = None
    for resource_tile in resource_tiles:
        if not (resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL): continue    
        dist = resource_tile.pos.distance_to(pos)
        if dist < closest_dist:
            closest_dist = dist
            closest_coal_tile = resource_tile
    return closest_coal_tile


def find_closest_city_tile_needing_fuel(pos, player):
    cities_needing_fuel = []
    city_stats = []
    for k, city in player.cities.items():
        city_stats.append([city, city.fuel])
        if city.fuel < city.get_light_upkeep()*5:
            cities_needing_fuel.append(city)
            
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        # the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
        # contains the information of all citytiles in that city
        for city in cities_needing_fuel:
            for city_tile in city.citytiles:
                dist = city_tile.pos.distance_to(pos)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_city_tile = city_tile
    return closest_city_tile

# %% [markdown]
# #### Functions to keep track of other units

# %%
def unit_will_collide(player, next_spot, positions_to_check):
    will_collide = False
    for location in positions_to_check:
        if next_spot.equals(location):
            will_collide = True
            break
    return will_collide

# %% [markdown]
# #### Functions to keep track of global metrics

# %%
def total_fuel_available(player):
    total_fuel_available = 0
    for k, city in player.cities.items():
        total_fuel_available += city.fuel
    return total_fuel_available

# %%
def time_to_night(game_state):
    if divmod(game_state.turn,40)[1]>=30:
        time_to_night = 0
    else:
        time_to_night= 30-divmod(game_state.turn,40)[1]
    return time_to_night

# %%
def move_to_a_city(player, unit, closest_city_tile, closest_city_tile_needing_fuel):
    action = None
    spot = None
    ### MOVE TO THE CLOSEST CITY TILE NEEDING FUEL IF IT EXISTS
    if closest_city_tile_needing_fuel is not None:
        spot = closest_city_tile_needing_fuel.pos
        action = unit.move(unit.pos.direction_to(spot))
        
    ### OTHERWISE MOVE TO THE CLOSEST CITY    
    else:
        if closest_city_tile is not None:
            spot = closest_city_tile.pos
            action = unit.move(unit.pos.direction_to(spot))
            
    return action, spot

def move_to_a_resource(player, unit, closest_resource_tile):
    action, spot = None, None
    if closest_resource_tile is not None:
        spot = closest_resource_tile.pos
        action = unit.move(unit.pos.direction_to(spot))
    return action, spot

def move_to_a_build_location(player, unit, closest_build_location):
    action, spot = None, None
    if closest_build_location is not None:
        spot = closest_build_location.pos
        action = unit.move(unit.pos.direction_to(spot))
    return action, spot
    
def move_randomly(player, unit, game_state):
    action = None
    directions = 'news'
    move_direction = random.choice(directions)
    if move_direction == 'n':
        if unit.pos.y-1 < 0 :
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y)
        else:
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y-1)
    elif move_direction == 's':
        if unit.pos.y + 1 >= game_state.map.height:
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y)
        else:
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y+1)
    elif move_direction == 'e':
        if unit.pos.x + 1 >= game_state.map.height:
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y)
        else:
            new_loc = game_state.map.get_cell(unit.pos.x+1, unit.pos.y)
    elif move_direction == 'w':
        if unit.pos.x-1 < 0 :
            new_loc = game_state.map.get_cell(unit.pos.x, unit.pos.y)
        else:
            new_loc = game_state.map.get_cell(unit.pos.x-1, unit.pos.y-1)
        
    spot = new_loc.pos
    action = unit.move(unit.pos.direction_to(spot))
           
    return action, spot

def ideal_build_locations(good_patches, player):
    build_locations = []
    for patch in good_patches:
        if 0 < patch[2] <= 3:
            for cell in find_city_adjacent_empty_tiles(player):
                build_locations.append(cell)
                break
        else:
            for x1 in range(patch[0][0], patch[0][0]+4):
                for y1 in range(patch[0][1], patch[0][1]+4):
                    cell = game_state.map.get_cell(x1, y1)
                    if cell.citytile is None and cell.has_resource() == False:
                        build_locations.append(cell)
    return(build_locations)

def find_closest_build_location(pos, player, build_locations):
    closest_build_location = None
    if len(build_locations) > 0:
        closest_dist = math.inf
        # the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
        # contains the information of all citytiles in that city
        for build_location in build_locations:
            dist = build_location.pos.distance_to(pos)
            if dist < closest_dist:
                closest_dist = dist
                closest_build_location = build_location
    return closest_build_location

# %%
def evaluate_patches(player, patches_info, city_tiles_positions, game_state):
    patch_score = 0
    for patch_info in patches_info:
        #patch score = resources in patch - 
        #              number of city tiles in patch - 
        #              number of enemy tiles in patch -
        
        distances = []
        for pos in city_tiles_positions:
            distances.append(pos.distance_to(game_state.map.get_cell(patch_info[0][0], patch_info[0][1]).pos))
        avg_distance_to_city_tiles = np.mean(distances)
        patch_score = 2*patch_info[1] - patch_info[3] - avg_distance_to_city_tiles
        patch_info.append(patch_score)
    
    return patches_info

# %% [markdown]
# #### worker actions policies

# %%
def worker_actions_policy(player, actions):    
    city_tiles_positions = []
    if len(player.cities) > 0:
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                city_tiles_positions.append(city_tile.pos)
    
    resource_tiles = find_resources(game_state)
    fuel_available = total_fuel_available(player)
    time_to_darkness = time_to_night(game_state)
    patches_info = find_resource_patches(game_state, player)
    top_5_patches = sorted(evaluate_patches(player, patches_info, city_tiles_positions, game_state), key=lambda x:x[4], reverse = True)[0:5]
     
                
    for gp in top_5_patches:
        actions.append(annotate.circle(gp[0][0], gp[0][1]))
        actions.append(annotate.sidetext(str(f"patch {gp[0]}, resource count =  {gp[1]}")))

    build_locations = ideal_build_locations(top_5_patches, player)    
    moving_to = []
    
    for unit in player.units:
        closest_resource_tile = find_closest_resources(unit.pos, player, resource_tiles)
        closest_city_tile = find_closest_city_tile(unit.pos, player)
        closest_city_tile_needing_fuel = find_closest_city_tile_needing_fuel(unit.pos, player)
        closest_build_location = find_closest_build_location(unit.pos, player, build_locations)
        
        if unit.is_worker() and unit.can_act():
            ### IF NIGHT IS FAR AWAY
            if time_to_darkness > 1:
                ### COLLECT RESOURCES AND DROP THEM OFF
                if unit.get_cargo_space_left() > 0: #COLLECT
                    proposed_action, proposed_spot = move_to_a_resource(player, unit, closest_resource_tile)
                    next_spot = unit.pos.translate(unit.pos.direction_to(proposed_spot),1)
                    if unit_will_collide(player, next_spot, moving_to): 
                        action, spot = move_randomly(player, unit, game_state)
                        next_spot = unit.pos.translate(unit.pos.direction_to(spot),1)
                    else:
                        action, spot = proposed_action, proposed_spot
                    moving_to.append(next_spot)
                    actions.append(action)

                else: #DROP OFF
                    ### IF NO CITY NEEDS FUEL
                    if closest_city_tile_needing_fuel is None:
                        ### TRY TO BUILD CITIES                        
                        if unit.can_build(game_state.map):
                            action = unit.build_city()
                            actions.append(action)
                        else:
                            proposed_action, proposed_spot = move_to_a_build_location(player, unit, closest_build_location)
                            next_spot = unit.pos.translate(unit.pos.direction_to(proposed_spot),1)
                            if unit_will_collide(player, next_spot, moving_to) or unit_will_collide(player, next_spot, city_tiles_positions):
                                action, spot = move_randomly(player, unit, game_state)
                                next_spot = unit.pos.translate(unit.pos.direction_to(spot),1)                                  
                            else:
                                action, spot = proposed_action, proposed_spot
                            moving_to.append(next_spot)
                            actions.append(action)
                            
                    ### BUT IF CITY NEEDS FUEL THEN MOVE TO THE CLOSEST CITY NEEDING FUEL
                    else:
                        actions.append(annotate.sidetext(str(f"city = {closest_city_tile_needing_fuel.pos.x, closest_city_tile_needing_fuel.pos.y} needs fuel!")))
                        proposed_action, proposed_spot = move_to_a_city(player, unit, closest_city_tile, closest_city_tile_needing_fuel)
                        next_spot = unit.pos.translate(unit.pos.direction_to(proposed_spot),1)
                        
                        if unit_will_collide(player, next_spot, moving_to):   
                            action, spot = move_randomly(player, unit, game_state)
                            next_spot = unit.pos.translate(unit.pos.direction_to(spot),1)
                        else:
                            action, spot = proposed_action, proposed_spot
                        moving_to.append(next_spot)
                        actions.append(action)
                        
            ### HEAD HOME IF NIGHT IS APPROACHING
            else:
                proposed_action, proposed_spot = move_to_a_city(player, unit, closest_city_tile, closest_city_tile_needing_fuel)
                next_spot = unit.pos.translate(unit.pos.direction_to(proposed_spot),1)

                if unit_will_collide(player, next_spot, moving_to):   
                    action, spot = move_randomly(player, unit, game_state)
                    next_spot = unit.pos.translate(unit.pos.direction_to(spot),1)
                else:
                    action, spot = proposed_action, proposed_spot
                moving_to.append(next_spot)
                actions.append(action)
           
    return actions


def city_actions_policy(player, actions):
    num_workers, num_carts = 0, 0
    for unit in player.units:
        if unit.is_worker():
            num_workers +=1
        else:
            num_carts +=1
    if len(player.cities) > 0:
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                if city_tile.can_act():
                    if player.city_tile_count > len(player.units):
                        if len(player.units) > 10 and num_carts/num_workers < 0.2:
                            action = city_tile.build_cart()
                        else:
                            action = city_tile.build_worker()
                        actions.append(action)
                    else:
                        action = city_tile.research()
                        actions.append(action)
                else:
                    continue        
    return actions
    
def cart_actions_policy(player, actions):
    for unit in player.units:
        if unit.is_cart() and unit.can_act():
            action, spot = move_randomly(player, unit, game_state)
            actions.append(action)
            
    return actions

# %% [markdown]
# #### Agent Code

# %%
game_state = None
def agent(observation, configuration):
    global game_state

    ### Do not edit ###
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation.player
    else:
        game_state._update(observation["updates"])
    
    actions = []

    ### AI Code goes down here! ### 
    player = game_state.players[observation.player]
    opponent = game_state.players[(observation.player + 1) % 2]
    width, height = game_state.map.width, game_state.map.height
    
    # add debug statements like so!
    if game_state.turn == 0:
        print("Agent is running!", file=sys.stderr)
        
    actions = city_actions_policy(player, actions)
    actions = worker_actions_policy(player, actions)
    #actions = cart_actions_policy(player, actions)
    
      
    return actions

# %%
seed = random.choice(range(1,562124222))
env = make("lux_ai_2021", configuration={"seed": seed, "loglevel": 2, "annotations": False}, debug=True)
env.run([agent, "simple_agent"])
env.render(mode = "ipython", width=800, height=600)
# Out:
# Agent is running!
# [WARN] (match_2Yiaqe6ZkaTy) - turn 12; Unit u_3 collided when trying to move w to (28, 4)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 14; Unit u_1 collided when trying to move w to (28, 4)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 19; Unit u_1 collided when trying to move s to (28, 6)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 6) but unit cap reached. Build more CityTiles!; turn 20; cmd: bw 28 6
# [WARN] (match_2Yiaqe6ZkaTy) - turn 21; Unit u_1 collided when trying to move n to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 23; Unit u_3 collided when trying to move n to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 23; Unit u_4 collided when trying to move s to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 24; Unit u_1 collided when trying to move c to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 24; Unit u_1 collided when trying to move c to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 24; Unit u_3 collided when trying to move n to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 24; Unit u_3 collided when trying to move n to (28, 5)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 44; Unit u_6 collided when trying to move w to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 45; Unit u_3 collided when trying to move n to (28, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 45; Unit u_6 collided when trying to move w to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 47; Unit u_1 collided when trying to move e to (28, 4)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 47; Unit u_3 collided when trying to move s to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (27, 3) but unit cap reached. Build more CityTiles!; turn 49; cmd: bw 27 3
# [WARN] (match_2Yiaqe6ZkaTy) - turn 49; Unit u_1 collided when trying to move e to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 50; Unit u_1 collided when trying to move e to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 50; Unit u_9 collided when trying to move s to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 50; Unit u_10 collided when trying to move n to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 51; Unit u_1 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 51; Unit u_8 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 52; Unit u_4 collided when trying to move n to (28, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 52; Unit u_7 collided when trying to move w to (29, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 53; Unit u_4 collided when trying to move w to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 54; Unit u_6 collided when trying to move e to (29, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 55; Unit u_6 collided when trying to move w to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 57; Unit u_3 collided when trying to move n to (29, 6)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 57; Unit u_8 collided when trying to move w to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 6) but unit cap reached. Build more CityTiles!; turn 58; cmd: bw 29 6
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 6) but unit cap reached. Build more CityTiles!; turn 59; cmd: bw 29 6
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (27, 7) but unit cap reached. Build more CityTiles!; turn 59; cmd: bw 27 7
# [WARN] (match_2Yiaqe6ZkaTy) - turn 60; Unit u_3 collided when trying to move w to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 60; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 60; Unit u_5 collided when trying to move w to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 60; Unit u_7 collided when trying to move w to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 60; Unit u_8 collided when trying to move n to (27, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 61; Unit u_8 collided when trying to move w to (26, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 62; Unit u_8 collided when trying to move w to (26, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 62; Unit u_10 collided when trying to move e to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 63; Unit u_8 collided when trying to move n to (27, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 63; Unit u_10 collided when trying to move e to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 63; Unit u_12 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (27, 1) but unit cap reached. Build more CityTiles!; turn 64; cmd: bc 27 1
# [WARN] (match_2Yiaqe6ZkaTy) - turn 64; Unit u_1 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 64; Unit u_6 collided when trying to move n to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 64; Unit u_10 collided when trying to move e to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 64; Unit u_12 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_1 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_6 collided when trying to move n to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_5 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_10 collided when trying to move e to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_7 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_4 collided when trying to move n to (25, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 65; Unit u_8 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 66; Unit u_1 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 66; Unit u_6 collided when trying to move n to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 68; Unit u_4 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 68; Unit u_9 collided when trying to move s to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 68; Unit u_8 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 71; Unit u_1 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 71; Unit u_6 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 74; Unit u_4 collided when trying to move s to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 74; Unit u_6 collided when trying to move e to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 75; Unit u_6 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 2) but unit cap reached. Build more CityTiles!; turn 76; cmd: bw 28 2
# [WARN] (match_2Yiaqe6ZkaTy) - turn 76; Unit u_19 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 76; Unit u_21 collided when trying to move s to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 77; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 78; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (27, 7) but unit cap reached. Build more CityTiles!; turn 80; cmd: bw 27 7
# [WARN] (match_2Yiaqe6ZkaTy) - turn 81; Unit u_23 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 82; Unit u_3 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 82; Unit u_23 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 82; Unit u_25 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 83; Unit u_3 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 83; Unit u_23 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 85; Unit u_20 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 87; Unit u_17 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 87; Unit u_26 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 89; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 90; Unit u_24 collided when trying to move e to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 90; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 91; Unit u_11 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 91; Unit u_16 collided when trying to move e to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 92; Unit u_11 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 92; Unit u_20 collided when trying to move s to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 92; Unit u_11 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 92; Unit u_23 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 92; Unit u_23 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 93; Unit u_3 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 93; Unit u_17 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 93; Unit u_24 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 93; Unit u_6 collided when trying to move w to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_16 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_3 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_24 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_17 collided when trying to move s to (28, 9)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_16 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 94; Unit u_24 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 95; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 96; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_16 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_24 collided when trying to move n to (28, 9)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 97; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_16 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_24 collided when trying to move n to (28, 9)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 98; Unit u_20 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_16 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_24 collided when trying to move n to (28, 9)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_17 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 99; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 100; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 100; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_3 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_20 collided when trying to move s to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_11 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_20 collided when trying to move s to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_27 collided when trying to move n to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 101; Unit u_27 collided when trying to move n to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_6 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_17 collided when trying to move e to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_24 collided when trying to move n to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_20 collided when trying to move s to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_11 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_17 collided when trying to move e to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 102; Unit u_20 collided when trying to move s to (29, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 103; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 104; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 104; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 104; Unit u_20 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_17 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_20 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_23 collided when trying to move s to (30, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_25 collided when trying to move w to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 105; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_6 collided when trying to move w to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_26 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_17 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_20 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_3 collided when trying to move s to (28, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 106; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 107; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 107; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 107; Unit u_17 collided when trying to move e to (30, 8)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 108; Unit u_3 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 108; Unit u_16 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 108; Unit u_24 collided when trying to move n to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 108; Unit u_17 collided when trying to move n to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 110; Unit u_6 collided when trying to move e to (28, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 110; Unit u_16 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (27, 7) but unit cap reached. Build more CityTiles!; turn 111; cmd: bw 27 7
# [WARN] (match_2Yiaqe6ZkaTy) - turn 114; Unit u_24 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 115; Unit u_16 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 115; Unit u_24 collided when trying to move s to (28, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 116; Unit u_11 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 116; Unit u_16 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 117; Unit u_20 collided when trying to move e to (30, 6)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 6) but unit cap reached. Build more CityTiles!; turn 121; cmd: bw 28 6
# [WARN] (match_2Yiaqe6ZkaTy) - turn 121; Unit u_36 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 122; Unit u_34 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 124; Unit u_33 collided when trying to move e to (29, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 129; Unit u_33 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 129; Unit u_33 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 129; Unit u_37 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 129; Unit u_37 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 130; Unit u_34 collided when trying to move n to (25, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (25, 0) but unit cap reached. Build more CityTiles!; turn 131; cmd: bw 25 0
# [WARN] (match_2Yiaqe6ZkaTy) - turn 132; Unit u_34 collided when trying to move s to (25, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_27 collided when trying to move n to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_36 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_33 collided when trying to move n to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_27 collided when trying to move n to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_36 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_35 collided when trying to move s to (25, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 134; Unit u_37 collided when trying to move s to (31, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 135; Unit u_24 collided when trying to move s to (28, 12)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 135; Unit u_29 collided when trying to move n to (28, 12)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 135; Unit u_36 collided when trying to move e to (31, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 135; Unit u_33 collided when trying to move n to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 135; Unit u_27 collided when trying to move n to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (31, 1) but unit cap reached. Build more CityTiles!; turn 136; cmd: bw 31 1
# [WARN] (match_2Yiaqe6ZkaTy) - turn 136; Unit u_27 collided when trying to move n to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 136; Unit u_36 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 136; Unit u_33 collided when trying to move n to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 136; Unit u_27 collided when trying to move n to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 136; Unit u_36 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 137; Unit u_33 collided when trying to move w to (29, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 137; Unit u_36 collided when trying to move s to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 137; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (30, 3) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 30 3
# [WARN] (match_2Yiaqe6ZkaTy) - turn 138; Unit u_23 collided when trying to move c to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 138; Unit u_23 collided when trying to move c to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 138; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 138; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 139; Unit u_35 collided when trying to move w to (25, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 140; Unit u_35 collided when trying to move w to (25, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 140; Unit u_36 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 140; Unit u_37 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 15) but unit cap reached. Build more CityTiles!; turn 141; cmd: bw 29 15
# [WARN] (match_2Yiaqe6ZkaTy) - turn 141; Unit u_36 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 141; Unit u_37 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_23 collided when trying to move c to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_23 collided when trying to move c to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_36 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_36 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_35 collided when trying to move w to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_39 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_43 collided when trying to move s to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_40 collided when trying to move n to (29, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_42 collided when trying to move n to (29, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 142; Unit u_44 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 144; Unit u_27 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 144; Unit u_27 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 144; Unit u_41 collided when trying to move e to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 144; Unit u_41 collided when trying to move e to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 144; Unit u_38 collided when trying to move s to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 145; Unit u_27 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 145; Unit u_27 collided when trying to move c to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 145; Unit u_41 collided when trying to move e to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 145; Unit u_41 collided when trying to move e to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 145; Unit u_32 collided when trying to move n to (29, 14)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 146; Unit u_24 collided when trying to move e to (30, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 146; Unit u_41 collided when trying to move n to (29, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 146; Unit u_43 collided when trying to move w to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 147; Unit u_39 collided when trying to move e to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 147; Unit u_43 collided when trying to move s to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 148; Unit u_23 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 148; Unit u_38 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 148; Unit u_27 collided when trying to move n to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 148; Unit u_42 collided when trying to move e to (30, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 149; Unit u_37 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 149; Unit u_38 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 149; Unit u_40 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 150; Unit u_38 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (25, 1) but unit cap reached. Build more CityTiles!; turn 151; cmd: bw 25 1
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 12) but unit cap reached. Build more CityTiles!; turn 151; cmd: bw 29 12
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 12) but unit cap reached. Build more CityTiles!; turn 152; cmd: bw 29 12
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 15) but unit cap reached. Build more CityTiles!; turn 152; cmd: bw 29 15
# [WARN] (match_2Yiaqe6ZkaTy) - turn 152; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (26, 2) but unit cap reached. Build more CityTiles!; turn 153; cmd: bc 26 2
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 12) but unit cap reached. Build more CityTiles!; turn 153; cmd: bc 29 12
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 15) but unit cap reached. Build more CityTiles!; turn 153; cmd: bc 29 15
# [WARN] (match_2Yiaqe6ZkaTy) - turn 153; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 153; Unit u_38 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 15) but unit cap reached. Build more CityTiles!; turn 154; cmd: bw 29 15
# [WARN] (match_2Yiaqe6ZkaTy) - turn 154; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (30, 3) but unit cap reached. Build more CityTiles!; turn 159; cmd: bw 30 3
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 6) but unit cap reached. Build more CityTiles!; turn 160; cmd: bw 29 6
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (30, 3) but unit cap reached. Build more CityTiles!; turn 160; cmd: bw 30 3
# [WARN] (match_2Yiaqe6ZkaTy) - turn 160; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 161; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 161; Unit u_52 collided when trying to move e to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 161; Unit u_62 collided when trying to move e to (28, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 162; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 162; Unit u_52 collided when trying to move e to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 162; Unit u_61 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 162; Unit u_62 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 164; Unit u_23 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 164; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 164; Unit u_60 collided when trying to move e to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 165; Unit u_46 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 165; Unit u_46 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 165; Unit u_59 collided when trying to move e to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 165; Unit u_59 collided when trying to move e to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 166; Unit u_36 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 166; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 167; Unit u_24 collided when trying to move s to (30, 12)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 168; Unit u_52 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 168; Unit u_57 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 168; Unit u_61 collided when trying to move w to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 168; Unit u_62 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_57 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_61 collided when trying to move w to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_62 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 169; Unit u_57 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 170; Unit u_36 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_23 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_23 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_46 collided when trying to move n to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_46 collided when trying to move n to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_37 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 171; Unit u_55 collided when trying to move w to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_23 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_23 collided when trying to move c to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_46 collided when trying to move n to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_46 collided when trying to move n to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_37 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_52 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_55 collided when trying to move w to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_61 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 172; Unit u_62 collided when trying to move w to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 173; Unit u_23 collided when trying to move n to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 173; Unit u_46 collided when trying to move n to (31, 3)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 173; Unit u_52 collided when trying to move s to (31, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 174; Unit u_52 collided when trying to move w to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 175; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 175; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 175; Unit u_62 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 175; Unit u_61 collided when trying to move n to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 175; Unit u_62 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 176; Unit u_57 collided when trying to move w to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 176; Unit u_62 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 176; Unit u_61 collided when trying to move n to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 176; Unit u_60 collided when trying to move w to (30, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 179; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 179; Unit u_55 collided when trying to move c to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 179; Unit u_61 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 179; Unit u_57 collided when trying to move w to (24, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 179; Unit u_61 collided when trying to move n to (24, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 181; Unit u_36 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 181; Unit u_55 collided when trying to move s to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 182; Unit u_36 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 182; Unit u_55 collided when trying to move s to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 182; Unit u_60 collided when trying to move w to (28, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_23 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_56 collided when trying to move n to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_56 collided when trying to move n to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_52 collided when trying to move w to (28, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 184; Unit u_59 collided when trying to move s to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 186; Unit u_37 collided when trying to move w to (25, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 186; Unit u_46 collided when trying to move n to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 187; Unit u_37 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 187; Unit u_62 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 188; Unit u_61 collided when trying to move w to (24, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 188; Unit u_62 collided when trying to move e to (27, 2)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 189; Unit u_55 collided when trying to move e to (27, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 189; Unit u_23 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 189; Unit u_62 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_23 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_55 collided when trying to move c to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_23 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_55 collided when trying to move c to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_57 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_57 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_36 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_61 collided when trying to move e to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_62 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_46 collided when trying to move n to (27, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_59 collided when trying to move c to (27, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_46 collided when trying to move n to (27, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 190; Unit u_59 collided when trying to move c to (27, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 191; Unit u_23 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 191; Unit u_57 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 200; Unit u_32 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 200; Unit u_73 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 201; Unit u_32 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 201; Unit u_73 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 201; Unit u_69 collided when trying to move w to (24, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 201; Unit u_70 collided when trying to move n to (26, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 202; Unit u_32 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 202; Unit u_73 collided when trying to move s to (29, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 202; Unit u_64 collided when trying to move s to (29, 7)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 207; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 207; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 207; Unit u_56 collided when trying to move s to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 207; Unit u_56 collided when trying to move s to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 208; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 208; Unit u_32 collided when trying to move c to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 208; Unit u_56 collided when trying to move s to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 208; Unit u_56 collided when trying to move s to (28, 13)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 212; Unit u_69 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_63 collided when trying to move w to (22, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_70 collided when trying to move e to (22, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 215; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 216; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 216; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 216; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 216; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 218; Unit u_63 collided when trying to move w to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 218; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 218; Unit u_74 collided when trying to move w to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_63 collided when trying to move w to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_69 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_72 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_73 collided when trying to move c to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_73 collided when trying to move c to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_77 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_64 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 219; Unit u_77 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 220; Unit u_63 collided when trying to move w to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 220; Unit u_69 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 220; Unit u_72 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_69 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_69 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_72 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_72 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_71 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_75 collided when trying to move s to (28, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 221; Unit u_56 collided when trying to move s to (28, 15)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (25, 0) but unit cap reached. Build more CityTiles!; turn 222; cmd: bw 25 0
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (25, 1) but unit cap reached. Build more CityTiles!; turn 222; cmd: bw 25 1
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 16) but unit cap reached. Build more CityTiles!; turn 222; cmd: bw 28 16
# [WARN] (match_2Yiaqe6ZkaTy) - turn 222; Unit u_71 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 222; Unit u_73 collided when trying to move n to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 222; Unit u_64 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 222; Unit u_71 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 222; Unit u_73 collided when trying to move n to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 223; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 223; Unit u_75 collided when trying to move s to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_72 collided when trying to move s to (20, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 224; Unit u_75 collided when trying to move e to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_56 collided when trying to move n to (28, 15)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_75 collided when trying to move n to (28, 15)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_72 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 225; Unit u_69 collided when trying to move n to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_56 collided when trying to move e to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_71 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 226; Unit u_72 collided when trying to move c to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_56 collided when trying to move e to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_71 collided when trying to move s to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_72 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_63 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 227; Unit u_72 collided when trying to move e to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 19) but unit cap reached. Build more CityTiles!; turn 228; cmd: bw 29 19
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_32 collided when trying to move c to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_32 collided when trying to move c to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_56 collided when trying to move s to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_56 collided when trying to move s to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_63 collided when trying to move c to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_63 collided when trying to move c to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 228; Unit u_70 collided when trying to move n to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 229; Unit u_56 collided when trying to move e to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 229; Unit u_64 collided when trying to move s to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 229; Unit u_32 collided when trying to move e to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 229; Unit u_75 collided when trying to move s to (28, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 230; Unit u_32 collided when trying to move e to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 230; Unit u_71 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 230; Unit u_56 collided when trying to move e to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 16) but unit cap reached. Build more CityTiles!; turn 233; cmd: bw 28 16
# [WARN] (match_2Yiaqe6ZkaTy) - turn 241; Unit u_87 collided when trying to move w to (24, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 244; Unit u_71 collided when trying to move n to (29, 16)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 244; Unit u_78 collided when trying to move e to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 244; Unit u_80 collided when trying to move n to (29, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 244; Unit u_81 collided when trying to move n to (29, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 244; Unit u_82 collided when trying to move n to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 16) but unit cap reached. Build more CityTiles!; turn 245; cmd: bw 29 16
# [WARN] (match_2Yiaqe6ZkaTy) - turn 245; Unit u_64 collided when trying to move c to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 245; Unit u_64 collided when trying to move c to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 245; Unit u_71 collided when trying to move s to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 245; Unit u_73 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 245; Unit u_71 collided when trying to move s to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 247; Unit u_71 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 247; Unit u_88 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 247; Unit u_78 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 247; Unit u_80 collided when trying to move e to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 247; Unit u_81 collided when trying to move n to (29, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_69 collided when trying to move w to (20, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_87 collided when trying to move w to (21, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_86 collided when trying to move w to (22, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_71 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_88 collided when trying to move s to (29, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_73 collided when trying to move e to (30, 17)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_78 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 248; Unit u_80 collided when trying to move e to (30, 0)
# ...
# [WARN] (match_2Yiaqe6ZkaTy) - turn 267; Unit u_90 collided when trying to move n to (28, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 267; Unit u_85 collided when trying to move n to (29, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 267; Unit u_89 collided when trying to move e to (29, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_71 collided when trying to move s to (29, 18)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_78 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_78 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_82 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_82 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_84 collided when trying to move e to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 268; Unit u_85 collided when trying to move n to (29, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 269; Unit u_81 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 269; Unit u_80 collided when trying to move n to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 269; Unit u_82 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 270; Unit u_89 collided when trying to move e to (29, 1)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 271; Unit u_82 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 281; Unit u_111 collided when trying to move w to (19, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 282; Unit u_111 collided when trying to move w to (19, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 285; Unit u_113 collided when trying to move e to (26, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 19) but unit cap reached. Build more CityTiles!; turn 286; cmd: bw 28 19
# [WARN] (match_2Yiaqe6ZkaTy) - turn 294; Unit u_80 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 294; Unit u_80 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 294; Unit u_112 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 294; Unit u_113 collided when trying to move e to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 294; Unit u_112 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 298; Unit u_110 collided when trying to move s to (29, 21)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 299; Unit u_113 collided when trying to move e to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 305; Unit u_117 collided when trying to move n to (29, 21)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 305; Unit u_110 collided when trying to move n to (29, 22)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_80 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_80 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_113 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_112 collided when trying to move n to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_113 collided when trying to move e to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_110 collided when trying to move n to (29, 22)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_114 collided when trying to move s to (29, 22)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_117 collided when trying to move n to (29, 21)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_110 collided when trying to move n to (29, 22)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 306; Unit u_114 collided when trying to move s to (29, 22)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 307; Unit u_112 collided when trying to move n to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 307; Unit u_113 collided when trying to move c to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 307; Unit u_112 collided when trying to move n to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 307; Unit u_113 collided when trying to move c to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 309; Unit u_61 collided when trying to move e to (13, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 309; Unit u_80 collided when trying to move w to (30, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 320; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 321; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 322; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 322; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 322; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 322; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 323; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 323; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 323; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 323; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 324; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 324; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 324; Unit u_80 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 324; Unit u_112 collided when trying to move c to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 326; Unit u_112 collided when trying to move n to (31, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (20, 0) but unit cap reached. Build more CityTiles!; turn 330; cmd: bw 20 0
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (30, 23) but unit cap reached. Build more CityTiles!; turn 330; cmd: bw 30 23
# [WARN] (match_2Yiaqe6ZkaTy) - turn 335; Unit u_61 collided when trying to move e to (13, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (28, 19) but unit cap reached. Build more CityTiles!; turn 337; cmd: bw 28 19
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (29, 25) but unit cap reached. Build more CityTiles!; turn 337; cmd: bw 29 25
# [WARN] (match_2Yiaqe6ZkaTy) - turn 338; Unit u_110 collided when trying to move n to (29, 24)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 339; Unit u_61 collided when trying to move w to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 339; Unit u_111 collided when trying to move c to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 339; Unit u_61 collided when trying to move w to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 339; Unit u_111 collided when trying to move c to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 340; Unit u_61 collided when trying to move w to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 340; Unit u_111 collided when trying to move c to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 340; Unit u_61 collided when trying to move w to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 340; Unit u_111 collided when trying to move c to (12, 0)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 340; Unit u_120 collided when trying to move w to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 342; Unit u_119 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 344; Unit u_110 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - Agent 0 tried to build unit on tile (21, 9) but unit cap reached. Build more CityTiles!; turn 346; cmd: bc 21 9
# [WARN] (match_2Yiaqe6ZkaTy) - turn 346; Unit u_119 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 348; Unit u_110 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 353; Unit u_127 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 354; Unit u_127 collided when trying to move s to (29, 23)
# [WARN] (match_2Yiaqe6ZkaTy) - turn 355; Unit u_127 collided when trying to move s to (29, 23)
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;334f6e69-554b-11ec-806c-00dbdf97725e&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 190595641,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: false,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;number&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r coal 0 5 401&quot;,
#               &quot;r wood 0 8 329&quot;,
#               &quot;r wood 0 9 363&quot;,
#               &quot;r wood 0 22 363&quot;,
#               &quot;r wood 0 23 329&quot;,
#               &quot;r coal 0 26 401&quot;,
#               &quot;r uranium 1 13 315&quot;,
#               &quot;r uranium 1 18 315&quot;,
#               &quot;r wood 2 0 395&quot;,
#               &quot;r uranium 2 13 305&quot;,
#               &quot;r uranium 2 14 345&quot;,
#               &quot;r uranium 2 17 345&quot;,
#               &quot;r uranium 2 18 305&quot;,
#               &quot;r wood 2 31 395&quot;,
#               &quot;r wood 3 0 367&quot;,
#               &quot;r wood 3 1 320&quot;,
#               &quot;r uranium 3 13 304&quot;,
#               &quot;r uranium 3 14 306&quot;,
#               &quot;r uranium 3 17 306&quot;,
#               &quot;r uranium 3 18 304&quot;,
#               &quot;r wood 3 30 320&quot;,
#               &quot;r wood 3 31 367&quot;,
#               &quot;r uranium 4 13 342&quot;,
#               &quot;r uranium 4 18 342&quot;,
#               &quot;r coal 8 0 414&quot;,
#               &quot;r coal 8 31 414&quot;,
#               &quot;r coal 11 12 403&quot;,
#               &quot;r coal 11 13 424&quot;,
#               &quot;r

# %% [markdown]
# #### Run the game  --- #original seed 562124210

# %%
# for i in range(10):
#     successful_games = 0
#     seed = random.choice(range(1,562124222))
#     env = make("lux_ai_2021", configuration={"seed": seed, "loglevel": 0, "annotations": False}, debug=True)
#     steps = env.run([agent, "simple_agent"])
#     rewards = []
#     for step in steps:
#         rewards.append(step[0].reward)
#     if len(steps) == 361:
#         successful_games +=1
#         print(f"In game map = {seed}")
#         print(f"Agent survived till step = {len(steps)}")
#         print(f"average reward reached = {np.mean(rewards)}")
#         print(f"max reward reached = {np.max(rewards)}")
#         if np.max(rewards) > 20000:
#             env.render(mode="ipython", width=720, height=480)
# print(f"Success rate = {successful_games* 100/10}")
